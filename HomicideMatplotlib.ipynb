# %%
import pandas as pd

# %%
# import data set to df
df = pd.read_csv('database.csv')
df.head()
# Out:
# C:\Users\cmilb\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Record ID Agency Code Agency Name       Agency Type       City   State  \
# 0          1     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 1          2     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 2          3     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 3          4     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 4          5     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
#
#    Year    Month  Incident              Crime Type  ... Victim Ethnicity  \
# 0  1980  January         1  Murder or Manslaughter  ...          Unknown
# 1  1980    March         1  Murder or Manslaughter  ...          Unknown
# ...

# %%
list(df.columns.values)

# %%
counts= df.groupby(['State', 'Year']).agg({'Year':['count']})
counts.reset_index(inplace = True)
counts.head(100)
# Out:
#       State  Year
#                   count
# 0   Alabama  1980   513
# 1   Alabama  1981   453
# 2   Alabama  1982   424
# 3   Alabama  1983   372
# 4   Alabama  1984   382
# ..      ...   ...   ...
# 95  Arizona  2006   509
# 96  Arizona  2007   516
# 97  Arizona  2008   403
# 98  Arizona  2009   370
# 99  Arizona  2010   400
#
# [100 rows x 3 columns]

# %%
state_df = df.groupby(['State'])
state_df.head()
# Out:
#        Record ID Agency Code Agency Name       Agency Type       City  \
# 0              1     AK00101   Anchorage  Municipal Police  Anchorage
# 1              2     AK00101   Anchorage  Municipal Police  Anchorage
# 2              3     AK00101   Anchorage  Municipal Police  Anchorage
# 3              4     AK00101   Anchorage  Municipal Police  Anchorage
# 4              5     AK00101   Anchorage  Municipal Police  Anchorage
# ...          ...         ...         ...               ...        ...
# 23058      23059     WY00101     Laramie  Municipal Police     Albany
# 23059      23060     WY00300    Campbell           Sheriff   Campbell
# 23060      23061     WY00400      Carbon           Sheriff     Carbon
# 23061      23062     WY00400      Carbon           Sheriff     Carbon
# 23062      23063     WY00401     Rawlins  Municipal Police     Carbon
#
#          State  Year     Month  Incident              Crime Type  ...  \
# ...

# %%
year = df.groupby(['Year'])
year.head()
# Out:
#         Record ID Agency Code Agency Name       Agency Type       City  \
# 0               1     AK00101   Anchorage  Municipal Police  Anchorage
# 1               2     AK00101   Anchorage  Municipal Police  Anchorage
# 2               3     AK00101   Anchorage  Municipal Police  Anchorage
# 3               4     AK00101   Anchorage  Municipal Police  Anchorage
# 4               5     AK00101   Anchorage  Municipal Police  Anchorage
# ...           ...         ...         ...               ...        ...
# 624123     624124     AK00101   Anchorage  Municipal Police  Anchorage
# 624124     624125     AK00101   Anchorage  Municipal Police  Anchorage
# 624125     624126     AK00101   Anchorage  Municipal Police  Anchorage
# 624126     624127     AK00101   Anchorage  Municipal Police  Anchorage
# 624127     624128     AK00101   Anchorage  Municipal Police  Anchorage
#
#          State  Year     Month  Incident                  Crime Type  ...  \
# ...

# %%
# count of homicide by state
state_homicide_count_state= state_df['Crime Type'].count()
# Out:
# State
# Alabama                 11376
# Alaska                   1617
# Arizona                 12871
# Arkansas                 6947
# California              99783
# Colorado                 6593
# Connecticut              4896
# Delaware                 1179
# District of Columbia     7115
# Florida                 37164
# Georgia                 21088
# Hawaii                   1338
# Idaho                    1150
# Illinois                25871
# Indiana                 11463
# Iowa                     1749
# Kansas                   3085
# Kentucky                 6554
# Louisiana               19629
# Maine                     869
# Maryland                17312
# Massachusetts            6036
# Michigan                28448
# Minnesota                3975
# Mississippi              6546
# Missouri                14832
# Montana                   601
# Nebraska                 1331
# Nevada                   5553
# New Hampshire             655
# New Jersey              14132
# ...

# %%
homicide_counts = state_homicide_count_year['Crime Type'].count()

# %%
murder_counts = {'State': state_df,
                 'Year': year,
    'Total Murder': state_homicide_count_state
}
murder_totals = pd.DataFrame(murder_counts)
murder_totals.head()
# Out:
# C:\Users\cmilb\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1229: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   v = np.array(v, copy=False)
# C:\Users\cmilb\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1623: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   subarr = np.array(values, dtype=dtype, copy=copy)
# ...
